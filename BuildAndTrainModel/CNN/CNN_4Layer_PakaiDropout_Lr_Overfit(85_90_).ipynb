# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.6.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gunavenkatdoddi/eye-diseases-classification/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gunavenkatdoddi/eye-diseases-classification/versions/
# License(s): ODbL-1.0
# Downloading eye-diseases-classification.zip to /content
# 100% 733M/736M [00:33<00:00, 24.7MB/s]
# 100% 736M/736M [00:33<00:00, 23.0MB/s]

# %% [markdown]
# **# Data Preprocessing Dan Data Exploration**

# %%
import zipfile

with zipfile.ZipFile('eye-diseases-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('eye-diseases-classification')

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Definisikan lokasi folder dataset
dataset_folder = "/content/eye-diseases-classification/dataset"

# Buat dictionary untuk menyimpan jumlah sampel setiap kelas
class_counts = {}

# Loop melalui setiap kelas
for class_name in os.listdir(dataset_folder):
    class_folder = os.path.join(dataset_folder, class_name)

    # Pastikan yang di-loop adalah folder, bukan file
    if os.path.isdir(class_folder):
        # Hitung jumlah gambar dalam setiap kelas
        num_images = len(os.listdir(class_folder))
        class_counts[class_name] = num_images

        # Tampilkan beberapa contoh gambar dari setiap kelas
        print(f"Class: {class_name} - Jumlah Sampel: {num_images}")
        print("-----------------------------------------------------")
        plt.figure(figsize=(10, 5))
        for i, image_file in enumerate(os.listdir(class_folder)[:3]):
            # Path lengkap menuju gambar
            image_path = os.path.join(class_folder, image_file)
            # Membaca dan menampilkan gambar menggunakan Matplotlib
            plt.subplot(1, 3, i + 1)
            image = mpimg.imread(image_path)
            plt.imshow(image)
            plt.title(f"Sample {i + 1}")
            plt.axis('off')  # Menghilangkan sumbu
        plt.show()
        print("\n")

# Tampilkan distribusi sampel setiap kelas
plt.figure(figsize=(10, 5))
plt.bar(class_counts.keys(), class_counts.values())
plt.title('Distribusi Sampel Setiap Kelas')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=45)
plt.show()
# Out:
# Class: normal - Jumlah Sampel: 1074
# -----------------------------------------------------
# Class: cataract - Jumlah Sampel: 1038
# -----------------------------------------------------
# Class: diabetic_retinopathy - Jumlah Sampel: 1098
# -----------------------------------------------------
# Class: glaucoma - Jumlah Sampel: 1007
# -----------------------------------------------------

# %% [markdown]
# # **Split Model**

# %%
import os
import shutil
import random
from sklearn.model_selection import train_test_split

# Direktori dataset
dataset_dir = "/content/eye-diseases-classification/dataset/"

# List tiap Class
classes = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]

# Ratio train, validation, dan test sets
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Loop tiap class
for class_name in classes:
    # Path to the current class directory
    class_dir = os.path.join(dataset_dir, class_name)

    # List all files in the class directory
    files = os.listdir(class_dir)

    # Split files into train, val, test using sklearn train_test_split twice
    # First split: train (80%), remaining (20%)
    train_files, remaining_files = train_test_split(files, train_size=train_ratio, random_state=42)

    # Second split: val (10%), test (10%)
    val_files, test_files = train_test_split(remaining_files, train_size=0.5, random_state=42)

    # Membuat direktori baru train, validation, dan test sets
    for folder_name, file_list in [("train", train_files), ("val", val_files), ("test", test_files)]:
        folder_path = os.path.join(dataset_dir, folder_name, class_name)
        os.makedirs(folder_path, exist_ok=True)

        # Pindah file ke tempat yang sesuai dengan class
        for file in file_list:
            src = os.path.join(class_dir, file)
            dst = os.path.join(folder_path, file)
            shutil.move(src, dst)

# %% [markdown]
# # **Data Augmentation Dan Normalization **

# %%
from keras.preprocessing.image import ImageDataGenerator

# Direktori dataset
dataset_dir = "/content/eye-diseases-classification/dataset/"

# Dimensi sebuah gambar
img_width, img_height = 256, 256

# ukuran Batch image
batch_size = 32

# Data augmentation dan normalization
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0,1]
 )
val_datagen = ImageDataGenerator(rescale=1./255)  #  normalization for validation set
test_datagen = ImageDataGenerator(rescale=1./255)  # normalization for test set

# Data generators
train_generator = train_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'train'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

val_generator = val_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'val'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'test'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 3372 images belonging to 4 classes.
# Found 422 images belonging to 4 classes.
# Found 423 images belonging to 4 classes.

# %% [markdown]
# Model CNN 5 Layer

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import Adam

# Mendefinisikan CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))  # Output layer dengan 4 kelas

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 14839492 (56.61 MB)
# Trainable params: 14839492 (56.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model dengan optimizer Adam dan learning rate yang diatur
optimizer = Adam(learning_rate=0.0001)  # Ganti 0.001 dengan nilai learning rate yang diinginkan
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=50,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size)

# evaluasi model
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 39s 280ms/step - loss: 1.0600 - accuracy: 0.5413 - val_loss: 0.8295 - val_accuracy: 0.6394
# Epoch 2/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.7890 - accuracy: 0.6593 - val_loss: 0.6800 - val_accuracy: 0.7260
# Epoch 3/50
# 105/105 [==============================] - 27s 255ms/step - loss: 0.6890 - accuracy: 0.7123 - val_loss: 0.6344 - val_accuracy: 0.7380
# Epoch 4/50
# 105/105 [==============================] - 27s 262ms/step - loss: 0.6308 - accuracy: 0.7416 - val_loss: 0.5628 - val_accuracy: 0.7837
# Epoch 5/50
# 105/105 [==============================] - 27s 254ms/step - loss: 0.6012 - accuracy: 0.7569 - val_loss: 0.5351 - val_accuracy: 0.8053
# Epoch 6/50
# 105/105 [==============================] - 27s 261ms/step - loss: 0.5275 - accuracy: 0.7808 - val_loss: 0.4700 - val_accuracy: 0.8293
# Epoch 7/50
# 105/105 [==============================] - 27s 256ms/step - loss: 0.5220 - accuracy: 0.7838 - val_loss: 0.4788 - val_accuracy: 0.8053
# Epoch 8/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.5016 - accuracy: 0.7958 - val_loss: 0.4560 - val_accuracy: 0.8317
# Epoch 9/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.4915 - accuracy: 0.8015 - val_loss: 0.4322 - val_accuracy: 0.8389
# Epoch 10/50
# 105/105 [==============================] - 28s 265ms/step - loss: 0.4501 - accuracy: 0.8216 - val_loss: 0.4781 - val_accuracy: 0.8053
# Epoch 11/50
# 105/105 [==============================] - 26s 248ms/step - loss: 0.4413 - accuracy: 0.8275 - val_loss: 0.4001 - val_accuracy: 0.8510
# Epoch 12/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.4555 - accuracy: 0.8201 - val_loss: 0.4551 - val_accuracy: 0.8293
# Epoch 13/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.4156 - accuracy: 0.8341 - val_loss: 0.3881 - val_accuracy: 0.8582
# Epoch 14/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.4277 - accuracy: 0.8320 - val_loss: 0.3760 - val_accuracy: 0.8510
# Epoch 15/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.4048 - accuracy: 0.8407 - val_loss: 0.4109 - val_accuracy: 0.8462
# Epoch 16/50
# 105/105 [==============================] - 26s 247ms/step - loss: 0.3892 - accuracy: 0.8428 - val_loss: 0.3705 - val_accuracy: 0.8582
# Epoch 17/50
# 105/105 [==============================] - 26s 252ms/step - loss: 0.3912 - accuracy: 0.8431 - val_loss: 0.3536 - val_accuracy: 0.8870
# Epoch 18/50
# 105/105 [==============================] - 26s 251ms/step - loss: 0.3727 - accuracy: 0.8500 - val_loss: 0.3829 - val_accuracy: 0.8558
# Epoch 19/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.3669 - accuracy: 0.8566 - val_loss: 0.3607 - val_accuracy: 0.8702
# Epoch 20/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.3485 - accuracy: 0.8644 - val_loss: 0.3454 - val_accuracy: 0.8798
# Epoch 21/50
# 105/105 [==============================] - 27s 257ms/step - loss: 0.3470 - accuracy: 0.8623 - val_loss: 0.3796 - val_accuracy: 0.8582
# Epoch 22/50
# 105/105 [==============================] - 27s 252ms/step - loss: 0.3595 - accuracy: 0.8584 - val_loss: 0.3740 - val_accuracy: 0.8486
# Epoch 23/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.3318 - accuracy: 0.8722 - val_loss: 0.4137 - val_accuracy: 0.8173
# Epoch 24/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.3390 - accuracy: 0.8695 - val_loss: 0.3631 - val_accuracy: 0.8654
# Epoch 25/50
# 105/105 [==============================] - 26s 251ms/step - loss: 0.3194 - accuracy: 0.8695 - val_loss: 0.3639 - val_accuracy: 0.8726
# Epoch 26/50
# 105/105 [==============================] - 29s 274ms/step - loss: 0.3047 - accuracy: 0.8835 - val_loss: 0.3435 - val_accuracy: 0.8822
# Epoch 27/50
# 105/105 [==============================] - 26s 251ms/step - loss: 0.3089 - accuracy: 0.8778 - val_loss: 0.3282 - val_accuracy: 0.8822
# Epoch 28/50
# 105/105 [==============================] - 26s 248ms/step - loss: 0.2973 - accuracy: 0.8826 - val_loss: 0.3322 - val_accuracy: 0.8798
# Epoch 29/50
# 105/105 [==============================] - 26s 250ms/step - loss: 0.2961 - accuracy: 0.8805 - val_loss: 0.3351 - val_accuracy: 0.8630
# Epoch 30/50
# 105/105 [==============================] - 26s 251ms/step - loss: 0.2826 - accuracy: 0.8898 - val_loss: 0.3391 - val_accuracy: 0.8726
# Epoch 31/50
# 105/105 [==============================] - 27s 253ms/step - loss: 0.2701 - accuracy: 0.8961 - val_loss: 0.3186 - val_accuracy: 0.8870
# Epoch 32/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.2790 - accuracy: 0.8880 - val_loss: 0.3130 - val_accuracy: 0.8678
# Epoch 33/50
# 105/105 [==============================] - 27s 251ms/step - loss: 0.2880 - accuracy: 0.8850 - val_loss: 0.3319 - val_accuracy: 0.8678
# Epoch 34/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.2553 - accuracy: 0.9027 - val_loss: 0.3043 - val_accuracy: 0.8870
# Epoch 35/50
# 105/105 [==============================] - 26s 247ms/step - loss: 0.2518 - accuracy: 0.9069 - val_loss: 0.3336 - val_accuracy: 0.8798
# Epoch 36/50
# 105/105 [==============================] - 27s 261ms/step - loss: 0.2574 - accuracy: 0.8985 - val_loss: 0.3442 - val_accuracy: 0.8750
# Epoch 37/50
# 105/105 [==============================] - 27s 253ms/step - loss: 0.2528 - accuracy: 0.9045 - val_loss: 0.3508 - val_accuracy: 0.8606
# Epoch 38/50
# 105/105 [==============================] - 28s 265ms/step - loss: 0.2359 - accuracy: 0.9087 - val_loss: 0.3169 - val_accuracy: 0.8966
# Epoch 39/50
# 105/105 [==============================] - 28s 268ms/step - loss: 0.2249 - accuracy: 0.9075 - val_loss: 0.3243 - val_accuracy: 0.8870
# Epoch 40/50
# 105/105 [==============================] - 29s 279ms/step - loss: 0.2381 - accuracy: 0.9012 - val_loss: 0.3065 - val_accuracy: 0.8822
# Epoch 41/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.2294 - accuracy: 0.9132 - val_loss: 0.2952 - val_accuracy: 0.8990
# Epoch 42/50
# 105/105 [==============================] - 27s 254ms/step - loss: 0.2307 - accuracy: 0.9054 - val_loss: 0.3040 - val_accuracy: 0.8846
# Epoch 43/50
# 105/105 [==============================] - 27s 256ms/step - loss: 0.2183 - accuracy: 0.9183 - val_loss: 0.3438 - val_accuracy: 0.8822
# Epoch 44/50
# 105/105 [==============================] - 26s 252ms/step - loss: 0.2189 - accuracy: 0.9165 - val_loss: 0.3116 - val_accuracy: 0.8846
# Epoch 45/50
# 105/105 [==============================] - 29s 272ms/step - loss: 0.2038 - accuracy: 0.9177 - val_loss: 0.2936 - val_accuracy: 0.8990
# Epoch 46/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.1923 - accuracy: 0.9249 - val_loss: 0.2956 - val_accuracy: 0.9062
# Epoch 47/50
# 105/105 [==============================] - 27s 257ms/step - loss: 0.1985 - accuracy: 0.9234 - val_loss: 0.3033 - val_accuracy: 0.8966
# Epoch 48/50
# 105/105 [==============================] - 27s 254ms/step - loss: 0.1934 - accuracy: 0.9246 - val_loss: 0.3042 - val_accuracy: 0.9087
# Epoch 49/50
# 105/105 [==============================] - 28s 263ms/step - loss: 0.2091 - accuracy: 0.9183 - val_loss: 0.2862 - val_accuracy: 0.8894
# Epoch 50/50
# 105/105 [==============================] - 26s 252ms/step - loss: 0.1877 - accuracy: 0.9272 - val_loss: 0.2944 - val_accuracy: 0.8846
# 13/13 [==============================] - 3s 235ms/step - loss: 0.3241 - accuracy: 0.8678
# Test accuracy: 0.8677884340286255

# %% [markdown]
# # **Visualisasi Evaluasi Accuracy Model**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # **Evaluasi Mode Confusion Matrix, Precission, recall, dan F1-Score**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Ambil prediksi kelas dari model pada dataset uji
y_pred = np.argmax(model.predict(test_generator), axis=1)

# Ambil label sebenarnya dari dataset uji
y_true = test_generator.classes

# Hitung confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Definisikan kelas label (misalnya: cataract, diabetic_retinopathy, glaucoma, normal)
classes = ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']

# Tampilkan confusion matrix
plt.figure(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# Hitung dan tampilkan classification report (precision, recall, F1-score)
report = classification_report(y_true, y_pred, target_names=classes)
print(report)
# Out:
# 14/14 [==============================] - 4s 260ms/step
#                       precision    recall  f1-score   support
#
#             cataract       0.84      0.88      0.86       104
# diabetic_retinopathy       0.96      1.00      0.98       110
#             glaucoma       0.80      0.74      0.77       101
#               normal       0.83      0.81      0.82       108
#
#             accuracy                           0.86       423
#            macro avg       0.86      0.86      0.86       423
#         weighted avg       0.86      0.86      0.86       423
