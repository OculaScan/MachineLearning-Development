# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.6.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gunavenkatdoddi/eye-diseases-classification/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gunavenkatdoddi/eye-diseases-classification/versions/
# License(s): ODbL-1.0
# Downloading eye-diseases-classification.zip to /content
# 100% 736M/736M [00:25<00:00, 25.8MB/s]
# 100% 736M/736M [00:25<00:00, 30.3MB/s]

# %% [markdown]
# **# Data Preprocessing Dan Data Exploration**

# %%
import zipfile

with zipfile.ZipFile('eye-diseases-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('eye-diseases-classification')

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Definisikan lokasi folder dataset
dataset_folder = "/content/eye-diseases-classification/dataset"

# Buat dictionary untuk menyimpan jumlah sampel setiap kelas
class_counts = {}

# Loop melalui setiap kelas
for class_name in os.listdir(dataset_folder):
    class_folder = os.path.join(dataset_folder, class_name)

    # Pastikan yang di-loop adalah folder, bukan file
    if os.path.isdir(class_folder):
        # Hitung jumlah gambar dalam setiap kelas
        num_images = len(os.listdir(class_folder))
        class_counts[class_name] = num_images

        # Tampilkan beberapa contoh gambar dari setiap kelas
        print(f"Class: {class_name} - Jumlah Sampel: {num_images}")
        print("-----------------------------------------------------")
        plt.figure(figsize=(10, 5))
        for i, image_file in enumerate(os.listdir(class_folder)[:3]):
            # Path lengkap menuju gambar
            image_path = os.path.join(class_folder, image_file)
            # Membaca dan menampilkan gambar menggunakan Matplotlib
            plt.subplot(1, 3, i + 1)
            image = mpimg.imread(image_path)
            plt.imshow(image)
            plt.title(f"Sample {i + 1}")
            plt.axis('off')  # Menghilangkan sumbu
        plt.show()
        print("\n")

# Tampilkan distribusi sampel setiap kelas
plt.figure(figsize=(10, 5))
plt.bar(class_counts.keys(), class_counts.values())
plt.title('Distribusi Sampel Setiap Kelas')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=45)
plt.show()
# Out:
# Class: cataract - Jumlah Sampel: 1038
# -----------------------------------------------------
# Class: glaucoma - Jumlah Sampel: 1007
# -----------------------------------------------------
# Class: diabetic_retinopathy - Jumlah Sampel: 1098
# -----------------------------------------------------
# Class: normal - Jumlah Sampel: 1074
# -----------------------------------------------------

# %% [markdown]
# # **Split Model**

# %%
import os
import shutil
import random
from sklearn.model_selection import train_test_split

# Direktori dataset
dataset_dir = "/content/eye-diseases-classification/dataset/"

# List tiap Class
classes = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]

# Ratio train, validation, dan test sets
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Loop tiap class
for class_name in classes:
    # Path to the current class directory
    class_dir = os.path.join(dataset_dir, class_name)

    # List all files in the class directory
    files = os.listdir(class_dir)

    # Split files into train, val, test using sklearn train_test_split twice
    # First split: train (80%), remaining (20%)
    train_files, remaining_files = train_test_split(files, train_size=train_ratio, random_state=42)

    # Second split: val (10%), test (10%)
    val_files, test_files = train_test_split(remaining_files, train_size=0.5, random_state=42)

    # Membuat direktori baru train, validation, dan test sets
    for folder_name, file_list in [("train", train_files), ("val", val_files), ("test", test_files)]:
        folder_path = os.path.join(dataset_dir, folder_name, class_name)
        os.makedirs(folder_path, exist_ok=True)

        # Pindah file ke tempat yang sesuai dengan class
        for file in file_list:
            src = os.path.join(class_dir, file)
            dst = os.path.join(folder_path, file)
            shutil.move(src, dst)

# %% [markdown]
# # **Data Augmentation Dan Normalization **

# %%
from keras.preprocessing.image import ImageDataGenerator

# Direktori dataset
dataset_dir = "/content/eye-diseases-classification/dataset/"

# Dimensi sebuah gambar
img_width, img_height = 256, 256

# ukuran Batch image
batch_size = 32

# Data augmentation dan normalization
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0,1]
 )
val_datagen = ImageDataGenerator(rescale=1./255)  #  normalization for validation set
test_datagen = ImageDataGenerator(rescale=1./255)  # normalization for test set

# Data generators
train_generator = train_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'train'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

val_generator = val_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'val'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    directory=os.path.join(dataset_dir, 'test'),
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 3372 images belonging to 4 classes.
# Found 422 images belonging to 4 classes.
# Found 423 images belonging to 4 classes.

# %% [markdown]
# Model CNN 5 Layer

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import Adam

# Mendefinisikan CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))  # Output layer dengan 4 classes

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 512)       1180160
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 64)                1179712
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 2790660 (10.65 MB)
# Trainable params: 2790660 (10.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model dengan optimizer Adam dan learning rate yang diatur
optimizer = Adam(learning_rate=0.0001)  # Ganti 0.001 dengan nilai learning rate yang diinginkan
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=50,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size)

# evaluasi model
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 43s 271ms/step - loss: 1.3817 - accuracy: 0.2707 - val_loss: 1.3391 - val_accuracy: 0.4231
# Epoch 2/50
# 105/105 [==============================] - 27s 252ms/step - loss: 1.3107 - accuracy: 0.3662 - val_loss: 1.1613 - val_accuracy: 0.5072
# Epoch 3/50
# 105/105 [==============================] - 26s 248ms/step - loss: 1.2056 - accuracy: 0.4326 - val_loss: 1.0403 - val_accuracy: 0.5192
# Epoch 4/50
# 105/105 [==============================] - 31s 297ms/step - loss: 1.0938 - accuracy: 0.4883 - val_loss: 0.9336 - val_accuracy: 0.5337
# Epoch 5/50
# 105/105 [==============================] - 29s 277ms/step - loss: 1.0284 - accuracy: 0.5000 - val_loss: 0.8847 - val_accuracy: 0.5865
# Epoch 6/50
# 105/105 [==============================] - 27s 257ms/step - loss: 0.9845 - accuracy: 0.5162 - val_loss: 0.8126 - val_accuracy: 0.6082
# Epoch 7/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.9158 - accuracy: 0.5434 - val_loss: 0.7691 - val_accuracy: 0.6827
# Epoch 8/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.8709 - accuracy: 0.5746 - val_loss: 0.7940 - val_accuracy: 0.6514
# Epoch 9/50
# 105/105 [==============================] - 27s 253ms/step - loss: 0.8418 - accuracy: 0.5784 - val_loss: 0.6862 - val_accuracy: 0.6659
# Epoch 10/50
# 105/105 [==============================] - 29s 274ms/step - loss: 0.8159 - accuracy: 0.6015 - val_loss: 0.6332 - val_accuracy: 0.6635
# Epoch 11/50
# 105/105 [==============================] - 28s 263ms/step - loss: 0.7826 - accuracy: 0.6201 - val_loss: 0.6470 - val_accuracy: 0.7139
# Epoch 12/50
# 105/105 [==============================] - 30s 289ms/step - loss: 0.7692 - accuracy: 0.6341 - val_loss: 0.6608 - val_accuracy: 0.6827
# Epoch 13/50
# 105/105 [==============================] - 27s 255ms/step - loss: 0.7350 - accuracy: 0.6623 - val_loss: 0.5909 - val_accuracy: 0.7548
# Epoch 14/50
# 105/105 [==============================] - 26s 248ms/step - loss: 0.7320 - accuracy: 0.6686 - val_loss: 0.5694 - val_accuracy: 0.7692
# Epoch 15/50
# 105/105 [==============================] - 27s 256ms/step - loss: 0.7221 - accuracy: 0.6572 - val_loss: 0.5845 - val_accuracy: 0.7452
# Epoch 16/50
# 105/105 [==============================] - 27s 254ms/step - loss: 0.6688 - accuracy: 0.6898 - val_loss: 0.5381 - val_accuracy: 0.7692
# Epoch 17/50
# 105/105 [==============================] - 29s 271ms/step - loss: 0.6692 - accuracy: 0.6940 - val_loss: 0.5023 - val_accuracy: 0.8245
# Epoch 18/50
# 105/105 [==============================] - 28s 261ms/step - loss: 0.6583 - accuracy: 0.7069 - val_loss: 0.5093 - val_accuracy: 0.8221
# Epoch 19/50
# 105/105 [==============================] - 27s 256ms/step - loss: 0.6468 - accuracy: 0.7159 - val_loss: 0.5241 - val_accuracy: 0.8341
# Epoch 20/50
# 105/105 [==============================] - 26s 247ms/step - loss: 0.6299 - accuracy: 0.7210 - val_loss: 0.4814 - val_accuracy: 0.8510
# Epoch 21/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.5821 - accuracy: 0.7479 - val_loss: 0.4510 - val_accuracy: 0.8462
# Epoch 22/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.5946 - accuracy: 0.7425 - val_loss: 0.4375 - val_accuracy: 0.8245
# Epoch 23/50
# 105/105 [==============================] - 34s 320ms/step - loss: 0.5936 - accuracy: 0.7368 - val_loss: 0.4885 - val_accuracy: 0.8486
# Epoch 24/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.5608 - accuracy: 0.7581 - val_loss: 0.4652 - val_accuracy: 0.8510
# Epoch 25/50
# 105/105 [==============================] - 27s 261ms/step - loss: 0.5629 - accuracy: 0.7500 - val_loss: 0.4463 - val_accuracy: 0.8438
# Epoch 26/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.5540 - accuracy: 0.7461 - val_loss: 0.4363 - val_accuracy: 0.8606
# Epoch 27/50
# 105/105 [==============================] - 27s 256ms/step - loss: 0.5377 - accuracy: 0.7698 - val_loss: 0.4541 - val_accuracy: 0.8486
# Epoch 28/50
# 105/105 [==============================] - 25s 241ms/step - loss: 0.5389 - accuracy: 0.7623 - val_loss: 0.4344 - val_accuracy: 0.8293
# Epoch 29/50
# 105/105 [==============================] - 25s 240ms/step - loss: 0.5381 - accuracy: 0.7554 - val_loss: 0.4453 - val_accuracy: 0.8654
# Epoch 30/50
# 105/105 [==============================] - 26s 244ms/step - loss: 0.5454 - accuracy: 0.7506 - val_loss: 0.4670 - val_accuracy: 0.8173
# Epoch 31/50
# 105/105 [==============================] - 26s 245ms/step - loss: 0.5186 - accuracy: 0.7662 - val_loss: 0.3892 - val_accuracy: 0.8654
# Epoch 32/50
# 105/105 [==============================] - 26s 243ms/step - loss: 0.5033 - accuracy: 0.7740 - val_loss: 0.3733 - val_accuracy: 0.8726
# Epoch 33/50
# 105/105 [==============================] - 26s 247ms/step - loss: 0.5116 - accuracy: 0.7671 - val_loss: 0.3933 - val_accuracy: 0.8654
# Epoch 34/50
# 105/105 [==============================] - 27s 253ms/step - loss: 0.4886 - accuracy: 0.7792 - val_loss: 0.3695 - val_accuracy: 0.8606
# Epoch 35/50
# 105/105 [==============================] - 26s 246ms/step - loss: 0.4876 - accuracy: 0.7826 - val_loss: 0.3746 - val_accuracy: 0.8702
# Epoch 36/50
# 105/105 [==============================] - 27s 257ms/step - loss: 0.4933 - accuracy: 0.7790 - val_loss: 0.3729 - val_accuracy: 0.8702
# Epoch 37/50
# 105/105 [==============================] - 26s 248ms/step - loss: 0.4906 - accuracy: 0.7769 - val_loss: 0.4139 - val_accuracy: 0.8413
# Epoch 38/50
# 105/105 [==============================] - 26s 244ms/step - loss: 0.4874 - accuracy: 0.7907 - val_loss: 0.4020 - val_accuracy: 0.8606
# Epoch 39/50
# 105/105 [==============================] - 26s 249ms/step - loss: 0.4847 - accuracy: 0.7826 - val_loss: 0.3679 - val_accuracy: 0.8798
# Epoch 40/50
# 105/105 [==============================] - 29s 278ms/step - loss: 0.5037 - accuracy: 0.7728 - val_loss: 0.3754 - val_accuracy: 0.8750
# Epoch 41/50
# 105/105 [==============================] - 31s 292ms/step - loss: 0.4729 - accuracy: 0.7844 - val_loss: 0.3683 - val_accuracy: 0.8774
# Epoch 42/50
# 105/105 [==============================] - 32s 308ms/step - loss: 0.4677 - accuracy: 0.7880 - val_loss: 0.4294 - val_accuracy: 0.8510
# Epoch 43/50
# 105/105 [==============================] - 29s 275ms/step - loss: 0.4767 - accuracy: 0.7829 - val_loss: 0.3674 - val_accuracy: 0.8846
# Epoch 44/50
# 105/105 [==============================] - 31s 295ms/step - loss: 0.4717 - accuracy: 0.7829 - val_loss: 0.4218 - val_accuracy: 0.8510
# Epoch 45/50
# 105/105 [==============================] - 28s 268ms/step - loss: 0.4782 - accuracy: 0.7901 - val_loss: 0.3842 - val_accuracy: 0.8798
# Epoch 46/50
# 105/105 [==============================] - 31s 293ms/step - loss: 0.4485 - accuracy: 0.7961 - val_loss: 0.3455 - val_accuracy: 0.8822
# Epoch 47/50
# 105/105 [==============================] - 29s 274ms/step - loss: 0.4574 - accuracy: 0.7946 - val_loss: 0.3840 - val_accuracy: 0.8726
# Epoch 48/50
# 105/105 [==============================] - 28s 264ms/step - loss: 0.4373 - accuracy: 0.7997 - val_loss: 0.3840 - val_accuracy: 0.8702
# Epoch 49/50
# 105/105 [==============================] - 29s 275ms/step - loss: 0.4451 - accuracy: 0.7922 - val_loss: 0.3830 - val_accuracy: 0.8678
# Epoch 50/50
# 105/105 [==============================] - 29s 276ms/step - loss: 0.4384 - accuracy: 0.8051 - val_loss: 0.3811 - val_accuracy: 0.8534
# 13/13 [==============================] - 3s 252ms/step - loss: 0.3634 - accuracy: 0.8678
# Test accuracy: 0.8677884340286255

# %% [markdown]
# # **Visualisasi Evaluasi Accuracy Model**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # **Evaluasi Mode Confusion Matrix, Precission, recall, dan F1-Score**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Ambil prediksi kelas dari model pada dataset uji
y_pred = np.argmax(model.predict(test_generator), axis=1)

# Ambil label sebenarnya dari dataset uji
y_true = test_generator.classes

# Hitung confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Definisikan kelas label (misalnya: cataract, diabetic_retinopathy, glaucoma, normal)
classes = ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']

# Tampilkan confusion matrix
plt.figure(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# Hitung dan tampilkan classification report (precision, recall, F1-score)
report = classification_report(y_true, y_pred, target_names=classes)
print(report)
# Out:
# 14/14 [==============================] - 5s 331ms/step
#                       precision    recall  f1-score   support
#
#             cataract       0.86      0.85      0.85       104
# diabetic_retinopathy       0.98      1.00      0.99       110
#             glaucoma       0.75      0.83      0.79       101
#               normal       0.88      0.79      0.83       108
#
#             accuracy                           0.87       423
#            macro avg       0.87      0.87      0.87       423
#         weighted avg       0.87      0.87      0.87       423
